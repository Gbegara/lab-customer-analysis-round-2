# %%
import pandas as pd
import numpy as np

# %%
mca = pd.read_csv('marketing_customer_analysis.csv')
display(mca.head())
mca.shape
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
mca = mca.drop(['Unnamed: 0'], axis = 1)

# %%
display(mca.head())
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
mca = mca.drop_duplicates()
mca.shape
# Out:
# (10873, 25)

# %%
cols1 = []
for column in mca.columns:
    cols1.append(column.lower())
mca.columns = cols1
display(mca.head())
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
mca._get_numeric_data()
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
mca.select_dtypes(include= 'object').columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective to date', 'employmentstatus', 'gender', 'location code',
#        'marital status', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')

# %%
mca.isna().sum()
# Out:
# customer                            0
# state                             614
# customer lifetime value             0
# response                          614
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           623
# months since policy inception       0
# number of open complaints         623
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# ...

# %%
mca[mca['state'].isna()==True].head(60)
# Out:
#     customer state  customer lifetime value response  coverage  \
# 5    HO81102   NaN              4745.181764      NaN     Basic
# 11   GE63585   NaN              2420.711888      NaN     Basic
# 58   BR69566   NaN             14019.833140      NaN     Basic
# 62   UF44021   NaN              2108.493744      NaN     Basic
# 126  TE60343   NaN              4716.264294      NaN     Basic
# 131  QK24293   NaN              6265.343299      NaN  Extended
# 155  JG35886   NaN              4111.888285      NaN   Premium
# 168  FV22585   NaN              6960.920371      NaN  Extended
# 169  AU23837   NaN              5010.379310      NaN     Basic
# 190  VZ18907   NaN             21991.615980      NaN     Basic
# 226  VK57280   NaN              4727.354548      NaN     Basic
# 251  EA52579   NaN              7687.296987      NaN     Basic
# 270  KX23516   NaN              4455.843406      NaN  Extended
# 304  PP39078   NaN              5623.611187      NaN     Basic
# ...

# %%
noresponse= 'No'
mca['response'] = mca['response'].fillna(noresponse)
mca.isna().sum()
noclaims= 0
mca['months since last claim'] = mca['months since last claim'].fillna(noclaims)
mca.isna().sum()
nocomplaints= 0
mca['number of open complaints'] = mca['number of open complaints'].fillna(nocomplaints)
mca.isna().sum()
# Out:
# customer                            0
# state                             614
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim             0
# months since policy inception       0
# number of open complaints           0
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# ...

# %%
mca['vehicle size'].unique()
mca['vehicle size'].value_counts()
# Out:
# Medsize    7233
# Small      1962
# Large      1070
# Name: vehicle size, dtype: int64

# %%
nottype= 'Not known'
mca['vehicle type'] = mca['vehicle type'].fillna(nottype)
mca
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
vhclass= 'Four-Door Car'
mca['vehicle class'] = mca['vehicle class'].fillna(vhclass)
vhsize= 'Medsize'
mca['vehicle size'] = mca['vehicle size'].fillna(vhsize)

mca.isna().sum()
# Out:
# customer                           0
# state                            614
# customer lifetime value            0
# response                           0
# coverage                           0
# education                          0
# effective to date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim            0
# months since policy inception      0
# number of open complaints          0
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                      0
# vehicle size                       0
# vehicle type                       0
# dtype: int64

# %%
mca['state'].unique()
mca['state'].value_counts()
# Out:
# California    3548
# Oregon        2897
# Arizona       1934
# Nevada         992
# Washington     888
# Name: state, dtype: int64

# %%
unstate= 'Unknown'
mca['state'] = mca['state'].fillna(unstate)
mca.isna().sum()
# Out:
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# vehicle type                     0
# dtype: int64

# %%
from datetime import date, timedelta

mca['effective to date'] = pd.to_datetime(mca['effective to date'], errors='coerce')
mca
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     Unknown              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
#found this function because with the one in the class didnt work "https://stackoverflow.com/questions/26105804/extract-month-from-date-in-python"
mca['month'] = mca['effective to date'].dt.month
mca.dtypes
# Out:
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                 float64
# months since policy inception             int64
# number of open complaints               float64
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# ...

# %% [markdown]
# # Round 3

# %%
mca
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     Unknown              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
mca.describe().T
# Out:
#                                  count          mean           std  \
# customer lifetime value        10873.0   8016.881720   6884.829202
# income                         10873.0  37537.101444  30362.078350
# monthly premium auto           10873.0     93.216684     34.454801
# months since last claim        10873.0     14.277292     10.399697
# months since policy inception  10873.0     48.098777     27.929932
# number of open complaints      10873.0      0.361538      0.889177
# number of policies             10873.0      2.977467      2.397752
# total claim amount             10873.0    434.902879    292.233402
# month                          10873.0      1.466661      0.498910
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5768.830622
# income                            0.000000     0.000000  33811.000000
# monthly premium auto             61.000000    68.000000     83.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Show a plot of the total number of responses
sns.countplot(x= 'response', y= '' data=mca)
plt.show()

# %%
sns.countplot(x='sales channel', data=mca, hue= 'response')
plt.show()

# %%
sns.displot(data=mca, x='total claim amount', hue='response', binwidth=150, palette=["#9b59b6", "#ff0000"])
plt.show()

# %%
sns.displot(data=mca, x='income', hue='response', binwidth=10000, palette=["#9b59b6", "#ff0000"])
plt.show()
